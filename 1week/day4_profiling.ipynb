# %%
import pandas as pd
import seaborn as sns

titanic_df = sns.load_dataset("titanic")

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(titanic_df, title='Titanic Profileing report', explorative=True)
profile.to_file("day4_report_ydata.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 384.61it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import sweetviz as sv

report_sv = sv.analyze(titanic_df, target_feat='survived')
report_sv.show_html("day4_report_sweetviz.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report day4_report_sweetviz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from autoviz.AutoViz_Class import AutoViz_Class

report_av = AutoViz_Class()
report_av.AutoViz(titanic_df, depVar="survived")
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (891, 15)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  3
#     Number of Factor-Categorical Columns =  2
#     Number of String-Boolean Columns =  4
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     14 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Binary_Classification problem #####################
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# There are 107 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_34bc7_row0_col0, #T_34bc7_row0_col2, #T_34bc7_row0_col3, #T_34bc7_row0_col4, #T_34bc7_row0_col5, #T_34bc7_row1_col0, #T_34bc7_row1_col2, #T_34bc7_row1_col3, #T_34bc7_row1_col4, #T_34bc7_row1_col5, #T_34bc7_row2_col0, #T_34bc7_row2_col2, #T_34bc7_row2_col3, #T_34bc7_row2_col4, #T_34bc7_row2_col5, #T_34bc7_row3_col0, #T_34bc7_row3_col2, #T_34bc7_row3_col3, #T_34bc7_row3_col4, #T_34bc7_row3_col5, #T_34bc7_row4_col0, #T_34bc7_row4_col2, #T_34bc7_row4_col3, #T_34bc7_row4_col4, #T_34bc7_row4_col5, #T_34bc7_row5_col0, #T_34bc7_row5_col2, #T_34bc7_row5_col3, #T_34bc7_row5_col4, #T_34bc7_row5_col5, #T_34bc7_row6_col0, #T_34bc7_row6_col2, #T_34bc7_row6_col3, #T_34bc7_row6_col4, #T_34bc7_row6_col5, #T_34bc7_row7_col0, #T_34bc7_row7_col2, #T_34bc7_row7_col3, #T_34bc7_row7_col4, #T_34bc7_row7_col5, #T_34bc7_row8_col0, #T_34bc7_row8_col2, #T_34bc7_row8_col3, #T_34bc7_row8_col4, #T_34bc7_row8_col5, #T_34bc7_row9_col0, #T_34bc7_row9_col2, #T_34bc7_row9_col3, #T_34bc7_row9_col4, #T_34bc7_row9_col5, #T_34bc7_row10_col0, #T_34bc7_row10_col2, #T_34bc7_row10_col3, #T_34bc7_row10_col4, #T_34bc7_row10_col5, #T_34bc7_row11_col0, #T_34bc7_row11_col2, #T_34bc7_row11_col3, #T_34bc7_row11_col4, #T_34bc7_row11_col5, #T_34bc7_row12_col0, #T_34bc7_row12_col2, #T_34bc7_row12_col3, #T_34bc7_row12_col4, #T_34bc7_row12_col5, #T_34bc7_row13_col0, #T_34bc7_row13_col2, #T_34bc7_row13_col3, #T_34bc7_row13_col4, #T_34bc7_row13_col5, #T_34bc7_row14_col0, #T_34bc7_row14_col2, #T_34bc7_row14_col3, #T_34bc7_row14_col4, #T_34bc7_row14_col5 {
#   font-family: Segoe UI;
# }
# #T_34bc7_row0_col1, #T_34bc7_row1_col1, #T_34bc7_row3_col1, #T_34bc7_row4_col1, #T_34bc7_row5_col1, #T_34bc7_row6_col1, #T_34bc7_row7_col1, #T_34bc7_row8_col1, #T_34bc7_row9_col1, #T_34bc7_row11_col1, #T_34bc7_row12_col1, #T_34bc7_row13_col1, #T_34bc7_row14_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_34bc7_row2_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_34bc7_row10_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_34bc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34bc7_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_34bc7_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_34bc7_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_34bc7_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_34bc7_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_34bc7_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34bc7_level0_row0" class="row_heading level0 row0" >pclass</th>
#       <td id="T_34bc7_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_34bc7_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_34bc7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_34bc7_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_34bc7_row0_col4" class="data row0 col4" >3.000000</td>
#       <td id="T_34bc7_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row1" class="row_heading level0 row1" >sex</th>
#       <td id="T_34bc7_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_34bc7_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_34bc7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_34bc7_row1_col3" class="data row1 col3" ></td>
#       <td id="T_34bc7_row1_col4" class="data row1 col4" ></td>
#       <td id="T_34bc7_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_34bc7_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_34bc7_row2_col1" class="data row2 col1" >13.520408</td>
#       <td id="T_34bc7_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_34bc7_row2_col3" class="data row2 col3" >0.420000</td>
#       <td id="T_34bc7_row2_col4" class="data row2 col4" >80.000000</td>
#       <td id="T_34bc7_row2_col5" class="data row2 col5" >106 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 7 outliers greater than upper bound (67.50) or lower than lower bound(-8.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row3" class="row_heading level0 row3" >sibsp</th>
#       <td id="T_34bc7_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_34bc7_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_34bc7_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_34bc7_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_34bc7_row3_col4" class="data row3 col4" >8.000000</td>
#       <td id="T_34bc7_row3_col5" class="data row3 col5" >Column has 39 outliers greater than upper bound (2.50) or lower than lower bound(-1.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row4" class="row_heading level0 row4" >parch</th>
#       <td id="T_34bc7_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_34bc7_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_34bc7_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_34bc7_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_34bc7_row4_col4" class="data row4 col4" >6.000000</td>
#       <td id="T_34bc7_row4_col5" class="data row4 col5" >Column has 15 outliers greater than upper bound (2.50) or lower than lower bound(-1.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row5" class="row_heading level0 row5" >fare</th>
#       <td id="T_34bc7_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_34bc7_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_34bc7_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_34bc7_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_34bc7_row5_col4" class="data row5 col4" >512.329200</td>
#       <td id="T_34bc7_row5_col5" class="data row5 col5" >Column has 102 outliers greater than upper bound (73.20) or lower than lower bound(-31.04). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row6" class="row_heading level0 row6" >embarked</th>
#       <td id="T_34bc7_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_34bc7_row6_col1" class="data row6 col1" >0.255102</td>
#       <td id="T_34bc7_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_34bc7_row6_col3" class="data row6 col3" ></td>
#       <td id="T_34bc7_row6_col4" class="data row6 col4" ></td>
#       <td id="T_34bc7_row6_col5" class="data row6 col5" >2 missing values. Impute them with mean, median, mode, or a constant value such as 123., Mixed dtypes: has 2 different data types:  object, float,</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row7" class="row_heading level0 row7" >class</th>
#       <td id="T_34bc7_row7_col0" class="data row7 col0" >category</td>
#       <td id="T_34bc7_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_34bc7_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_34bc7_row7_col3" class="data row7 col3" ></td>
#       <td id="T_34bc7_row7_col4" class="data row7 col4" ></td>
#       <td id="T_34bc7_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_34bc7_level0_row8" class="row_heading level0 row8" >who</th>
#       <td id="T_34bc7_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_34bc7_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_34bc7_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_34bc7_row8_col3" class="data row8 col3" ></td>
#       <td id="T_34bc7_row8_col4" class="data row8 col4" ></td>
#       <td id="T_34bc7_row8_col5" class="data row8 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_3
# Total Number of Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 2 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
#      pclass   sex     age  sibsp  parch   fare   embarked  class   who    \
# 0       3      male  22.0    1      0     7.2500     S      Third    man
# 1       1    female  38.0    1      0    71.2833     C      First  woman
# 2       3    female  26.0    0      0     7.9250     S      Third  woman
# 3       1    female  35.0    1      0    53.1000     S      First  woman
# 4       3      male  35.0    0      0     8.0500     S      Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886     2      male  27.0    0      0    13.0000     S     Second    man
# 887     1    female  19.0    0      0    30.0000     S      First  woman
# 888     3    female   NaN    1      2    23.4500     S      Third  woman
# 889     1      male  26.0    0      0    30.0000     C      First    man
# 890     3      male  32.0    0      0     7.7500     Q      Third    man
#
#      adult_male deck embark_town  alive  alone  survived
# 0        True    NaN  Southampton    no  False      0
# 1       False      C    Cherbourg   yes  False      1
# 2       False    NaN  Southampton   yes   True      1
# 3       False      C  Southampton   yes  False      1
# 4        True    NaN  Southampton    no   True      0
# ..          ...  ...          ...   ...    ...       ...
# 886      True    NaN  Southampton    no   True      0
# 887     False      B  Southampton   yes   True      1
# 888     False    NaN  Southampton    no  False      0
# 889      True      C    Cherbourg   yes   True      1
# 890      True    NaN   Queenstown    no   True      0
#
# [891 rows x 15 columns]

# %%
import dtale

d = dtale.show(titanic_df, host='localhost', port=5000)
d.open_browser()
